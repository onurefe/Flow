# %%
from obspy import read

# %%
st = read('/home/onur/2011/08/00/20110908_000000e.hybl.sac', debug_headers=True)

# %%
st
# Out:
# 1 Trace(s) in Stream:
# .hybl..e | 2011-09-08T00:00:00.000000Z - 2011-09-08T00:59:59.998220Z | 500.0 Hz, 1800000 samples

# %%
st.plot()
